# %% [markdown]
# # Pandas DataFrame Intro
#
# This notebook demonstrates how to work with a Pandas DataFrame.
# We will:
#
# - Load data from `data/symbol_info_3-25.csv` file, randomly sampling 25 rows, and selecting the desired columns.
# - Display general information about the DataFrame.
# - Show the content by position and by column
# - Sort the DataFrame by `Market_cap`.
# - Add a column with the percentage of each `Market_cap` relative to the total market cap.
# - Grouping and aggregation
# - Advanced Sorting and indexing
# - Filtering
# - Operations on non-numerical columns

# %% [markdown]
# ## Loading and Sampling Data
#
# We start by loading a CSV file into a DataFrame, then randomly selecting 25 rows and keeping only the columns we need: `symbol`, `market_cap`, and `sector`.

# %%
# Import the pandas library (the main tool for working with tabular data in Python)
import pandas as pd

# Load all data from the CSV file into a DataFrame
df = pd.read_csv('data/symbol_info_3-25.csv')

# Randomly pick 25 rows from the full dataset
# random_state=42 ensures we always get the same 25 rows (for reproducibility)
df_sample = df.sample(25, random_state=42)

# Keep only the 3 columns we need
df_sample = df_sample[['symbol', 'market_cap', 'sector']]

# Display the result
print('--- Initial Sampled DataFrame ---')
print(df_sample)
# Out:
# --- Initial Sampled DataFrame ---
#     symbol    market_cap              sector
# 521    EME   18167234560         Industrials
# 737   WTRG   10683482112           Utilities
# 740   COHR   10647828480          Technology
# 660     SN   12547034112   Consumer Cyclical
# 411    ROL   25068689408   Consumer Cyclical
# 678    BXP   12082990080         Real Estate
# 626    IEX   13923810304         Industrials
# 513      L   18602571776  Financial Services
# 859   CACI    8287675392          Technology
# 136   EQIX   82899656704         Real Estate
# 811    OGE    9103995904           Utilities
# 76     UNP  141880508416         Industrials
# 636    CNA   13326393344  Financial Services
# 973   BBIO    6612871168          Healthcare
# 938   RVMD    7148292608          Healthcare
# 899    GPK    7802572288   Consumer Cyclical
# 280    GLW   41688969216          Technology
# 883   GNRC    7950121472         Industrials
# 761    MTZ   10036755456         Industrials
# 319    SYY   34828255232  Consumer Defensive
# 549    ZTO   16714461184         Industrials
# 174   PYPL   69434900480  Financial Services
# 371   DXCM   29350852608          Healthcare
# 527    KEY   17847687168  Financial Services
# 210    MET   56351207424  Financial Services

# %% [markdown]
# ## Exploring the DataFrame
#
# Before working with data, it is important to understand its structure. We use:
#
# - **`.info()`** — shows column names, data types, and non-null counts
# - **`.describe()`** — gives summary statistics for numerical columns (mean, std, min, max, quartiles)
# - **`.describe(include='str')`** — gives summary statistics for text columns (count, unique values, most frequent)

# %%
# .info() prints a summary: column names, types, and how many non-null values
print('--- DataFrame Info ---')
df_sample.info()

# .describe() gives statistics for numerical columns (count, mean, std, min, max, quartiles)
print('\n--- DataFrame Description (numerical columns) ---')
print(df_sample.describe())

# .describe(include='str') gives statistics for text columns (count, unique values, most frequent)
print('\n--- DataFrame Description (text columns) ---')
print(df_sample.describe(include='object'))
# Out:
# --- DataFrame Info ---
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 521 to 210
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   symbol      25 non-null     object
#  1   market_cap  25 non-null     int64
#  2   sector      25 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 800.0+ bytes
#
# --- DataFrame Description (numerical columns) ---
#          market_cap
# count  2.500000e+01
# mean   2.731955e+10
# std    3.124412e+10
# min    6.612871e+09
# 25%    1.003676e+10
# 50%    1.392381e+10
# 75%    2.935085e+10
# max    1.418805e+11
#
# --- DataFrame Description (text columns) ---
#        symbol       sector
# count      25           25
# unique     25            8
# top       EME  Industrials
# freq        1            6

# %% [markdown]
# ## Accessing Rows by Position with `.iloc[]`
#
# `.iloc[]` lets you select rows by their **position** (like indexing a Python list). Position `0` is the first row, `-1` is the last, `-2` is the second-to-last, and so on.

# %%
# .iloc[] lets you access rows by their POSITION (like a list index)

# First row (position 0)
print('--- First Element (iloc[0]) ---')
print(df_sample.iloc[0])

# Access a specific column value from the first row
print('\n--- Market Cap of the first Element ---')
print(df_sample.iloc[0]['market_cap'])

# Last row (position -1, just like Python lists)
print('\n--- Last Element (iloc[-1]) ---')
print(df_sample.iloc[-1])

# Second-to-last row
print('\n--- Second-to-Last Element (iloc[-2]) ---')
print(df_sample.iloc[-2])
# Out:
# --- First Element (iloc[0]) ---
# symbol                EME
# market_cap    18167234560
# sector        Industrials
# Name: 521, dtype: object
#
# --- Market Cap of the first Element ---
# 18167234560
#
# --- Last Element (iloc[-1]) ---
# symbol                       MET
# market_cap           56351207424
# sector        Financial Services
# Name: 210, dtype: object
#
# --- Second-to-Last Element (iloc[-2]) ---
# symbol                       KEY
# market_cap           17847687168
# sector        Financial Services
# Name: 527, dtype: object

# %% [markdown]
# ## Sorting a DataFrame
#
# We can sort the rows of a DataFrame by any column using `.sort_values()`. Here we sort by `market_cap` in descending order (largest first).

# %%
# Sort the DataFrame by Market_cap
df_sorted = df_sample.sort_values(by='market_cap', ascending=False)
print('--- DataFrame Sorted by Market_cap ---')
print(df_sorted)
# Out:
# --- DataFrame Sorted by Market_cap ---
#     symbol    market_cap              sector
# 76     UNP  141880508416         Industrials
# 136   EQIX   82899656704         Real Estate
# 174   PYPL   69434900480  Financial Services
# 210    MET   56351207424  Financial Services
# 280    GLW   41688969216          Technology
# 319    SYY   34828255232  Consumer Defensive
# 371   DXCM   29350852608          Healthcare
# 411    ROL   25068689408   Consumer Cyclical
# 513      L   18602571776  Financial Services
# 521    EME   18167234560         Industrials
# 527    KEY   17847687168  Financial Services
# 549    ZTO   16714461184         Industrials
# 626    IEX   13923810304         Industrials
# 636    CNA   13326393344  Financial Services
# 660     SN   12547034112   Consumer Cyclical
# 678    BXP   12082990080         Real Estate
# 737   WTRG   10683482112           Utilities
# 740   COHR   10647828480          Technology
# 761    MTZ   10036755456         Industrials
# 811    OGE    9103995904           Utilities
# 859   CACI    8287675392          Technology
# 883   GNRC    7950121472         Industrials
# 899    GPK    7802572288   Consumer Cyclical
# 938   RVMD    7148292608          Healthcare
# 973   BBIO    6612871168          Healthcare

# %% [markdown]
# ## Operations on a Numerical Column
#
# Pandas provides many built-in functions to summarize a numerical column. Here are the most common ones applied to `market_cap`:
#
# | Function | What it does |
# |----------|-------------|
# | `.sum()` | Total of all values |
# | `.mean()` | Average (sum / count) |
# | `.median()` | Middle value when sorted |
# | `.min()` / `.max()` | Smallest / largest value |
# | `.std()` | Standard deviation (how spread out the values are) |
# | `.var()` | Variance (square of std) |
# | `.quantile([0.25, 0.5, 0.75])` | Values at the 25th, 50th, 75th percentiles |
#
# **Example usage:**
# ```python
# total_market_cap = df_sample['market_cap'].sum()
# average_market_cap = df_sample['market_cap'].mean()
# ```

# %%
#Exercise one
# Load all data from the CSV file into a DataFrame
import pandas as pd
df = pd.read_csv('data/symbol_info_3-25.csv')

# Randomly pick 30 rows from the full dataset
# random_state=42 ensures we always get the same 30 rows (for reproducibility). 
df_sample = df.sample(30, random_state=42)

#First of all we choose a quantitative variable from the data (enterprise_value) and I compute the mean 
average_enterprise_value = df_sample['enterprise_value'].mean()
print('The mean of the variable enterprise value is {}'.format(average_enterprise_value))

# I print all the values of variable enterprise_value
df_sample_enterprise = df_sample['enterprise_value']
print('----- Enterprise values ---')
print(df_sample_enterprise)
# Out:
# The mean of the variable enterprise value is 90602848102.4
# ----- Enterprise values ---
# 521      16978455552
# 737      18454824960
# 740      16518365184
# 660      12900748288
# 411      25722433536
# 678      29060794368
# 626      15252375552
# 513      22880147456
# 859      11469899776
# 136      97136320512
# 811      14598353920
# 76      172757499904
# 636      13978393600
# 973       7509071360
# 938       4931700736
# 899      12892424192
# 280      48276049920
# 883       8955035648
# 761      12001590272
# 319      47703121920
# 549      11656066048
# 174      70468927488
# 371      28853374976
# 527      32853676032
# 210      92796944384
# 235      57322881024
# 101    1787881062400
# 986      11104132096
# 902       7302352384
# 947       7868419584
# Name: enterprise_value, dtype: uint64

# %%
# Compare each value to the mean: 
# positive values mean above average, negative values mean below average

difference = df_sample_enterprise - average_enterprise_value
print('-------difference ---')
print(difference)
# Out:
# -------difference ---
# 521   -7.362439e+10
# 737   -7.214802e+10
# 740   -7.408448e+10
# 660   -7.770210e+10
# 411   -6.488041e+10
# 678   -6.154205e+10
# 626   -7.535047e+10
# 513   -6.772270e+10
# 859   -7.913295e+10
# 136    6.533472e+09
# 811   -7.600449e+10
# 76     8.215465e+10
# 636   -7.662445e+10
# 973   -8.309378e+10
# 938   -8.567115e+10
# 899   -7.771042e+10
# 280   -4.232680e+10
# 883   -8.164781e+10
# 761   -7.860126e+10
# 319   -4.289973e+10
# 549   -7.894678e+10
# 174   -2.013392e+10
# 371   -6.174947e+10
# 527   -5.774917e+10
# 210    2.194096e+09
# 235   -3.327997e+10
# 101    1.697278e+12
# 986   -7.949872e+10
# 902   -8.330050e+10
# 947   -8.273443e+10
# Name: enterprise_value, dtype: float64

# %% [markdown]
# ## Adding a Computed Column
#
# We can create a new column based on existing data. Here we compute the **percentage** that each company's market cap represents out of the total market cap of all 25 companies.

# %%
# --- Add a new column: percentage of total market cap ---

# First, compute the total market cap across all 25 companies
total_market_cap = df_sample['market_cap'].sum()

# Divide each company's market_cap by the total and multiply by 100 to get a percentage
df_sample['market_cap_%'] = (df_sample['market_cap'] / total_market_cap) * 100

print('--- DataFrame with Market Cap Percentage ---')
print(df_sample)

# --- Alternative ways to do the same thing (commented out for reference) ---

# Using apply() with a lambda (a one-line anonymous function):
# df_sample['market_cap_%'] = df_sample['market_cap'].apply(lambda x: (x / total_market_cap) * 100)

# Using apply() with a named function:
# def compute_percentage(value):
#     return (value / total_market_cap) * 100
# df_sample['market_cap_%'] = df_sample['market_cap'].apply(compute_percentage)
# Out:
# --- DataFrame with Market Cap Percentage ---
#     symbol                     company_name              sector  \
# 521    EME                EMCOR Group, Inc.         Industrials
# 737   WTRG        Essential Utilities, Inc.           Utilities
# 740   COHR                   Coherent Corp.          Technology
# 660     SN                 SharkNinja, Inc.   Consumer Cyclical
# 411    ROL                    Rollins, Inc.   Consumer Cyclical
# 678    BXP                        BXP, Inc.         Real Estate
# 626    IEX                 IDEX Corporation         Industrials
# 513      L                Loews Corporation  Financial Services
# 859   CACI         CACI International, Inc.          Technology
# 136   EQIX                    Equinix, Inc.         Real Estate
# 811    OGE                  OGE Energy Corp           Utilities
# 76     UNP        Union Pacific Corporation         Industrials
# 636    CNA        CNA Financial Corporation  Financial Services
# 973   BBIO           BridgeBio Pharma, Inc.          Healthcare
# 938   RVMD       Revolution Medicines, Inc.          Healthcare
# 899    GPK  Graphic Packaging Holding Compa   Consumer Cyclical
# 280    GLW             Corning Incorporated          Technology
# 883   GNRC           Generac Holdlings Inc.         Industrials
# 761    MTZ                     MasTec, Inc.         Industrials
# 319    SYY                Sysco Corporation  Consumer Defensive
# 549    ZTO        ZTO Express (Cayman) Inc.         Industrials
# 174   PYPL            PayPal Holdings, Inc.  Financial Services
# 371   DXCM                     DexCom, Inc.          Healthcare
# 527    KEY                          KeyCorp  Financial Services
# 210    MET                    MetLife, Inc.  Financial Services
# 235   PCAR                      PACCAR Inc.         Industrials
# 101    IBN               ICICI Bank Limited  Financial Services
# 986   VOYA             Voya Financial, Inc.  Financial Services
# 902   CELH           Celsius Holdings, Inc.  Consumer Defensive
# 947   CWST      Casella Waste Systems, Inc.         Industrials
#
#                                 industry    market_cap  enterprise_value  \
# 521           Engineering & Construction   18167234560       16978455552
# 737          Utilities - Regulated Water   10683482112       18454824960
# 740   Scientific & Technical Instruments   10647828480       16518365184
# 660   Furnishings, Fixtures & Appliances   12547034112       12900748288
# 411                    Personal Services   25068689408       25722433536
# 678                        REIT - Office   12082990080       29060794368
# 626       Specialty Industrial Machinery   13923810304       15252375552
# 513      Insurance - Property & Casualty   18602571776       22880147456
# 859      Information Technology Services    8287675392       11469899776
# 136                     REIT - Specialty   82899656704       97136320512
# 811       Utilities - Regulated Electric    9103995904       14598353920
# 76                             Railroads  141880508416      172757499904
# 636      Insurance - Property & Casualty   13326393344       13978393600
# 973                        Biotechnology    6612871168        7509071360
# 938                        Biotechnology    7148292608        4931700736
# 899               Packaging & Containers    7802572288       12892424192
# 280                Electronic Components   41688969216       48276049920
# 883       Specialty Industrial Machinery    7950121472        8955035648
# 761           Engineering & Construction   10036755456       12001590272
# 319                    Food Distribution   34828255232       47703121920
# First of all , I compute the total enterprise value across all 30 companies
total_enterprise_value = df_sample_2['enterprise_value'].sum()


# In a second moment I divide each company's enterprise_value by the total and multiply by 100 to get a percentage
df_sample_2['enterprise_value_percentage']  = (df_sample_2['enterprise_value']/total_enterprise_value)*100

print('--- DataFrame with Enterprise value percentage ---')
print(df_sample_2)
# Out:
# --- DataFrame with Enterprise value percentage ---
#     symbol  enterprise_value              sector  enterprise_value_percentage
# 521    EME       16978455552         Industrials                     0.624648
# 737   WTRG       18454824960           Utilities                     0.678964
# 740   COHR       16518365184          Technology                     0.607721
# 660     SN       12900748288   Consumer Cyclical                     0.474626
# 411    ROL       25722433536   Consumer Cyclical                     0.946344
# 678    BXP       29060794368         Real Estate                     1.069164
# 626    IEX       15252375552         Industrials                     0.561144
# 513      L       22880147456  Financial Services                     0.841774
# 859   CACI       11469899776          Technology                     0.421985
# 136   EQIX       97136320512         Real Estate                     3.573704
# 811    OGE       14598353920           Utilities                     0.537082
# 76     UNP      172757499904         Industrials                     6.355852
# 636    CNA       13978393600  Financial Services                     0.514274
# 973   BBIO        7509071360          Healthcare                     0.276263
# 938   RVMD        4931700736          Healthcare                     0.181440
# 899    GPK       12892424192   Consumer Cyclical                     0.474320
# 280    GLW       48276049920          Technology                     1.776105
# 883   GNRC        8955035648         Industrials                     0.329461
# 761    MTZ       12001590272         Industrials                     0.441546
# 319    SYY       47703121920  Consumer Defensive                     1.755027
# 549    ZTO       11656066048         Industrials                     0.428834
# 174   PYPL       70468927488  Financial Services                     2.592594
# 371   DXCM       28853374976          Healthcare                     1.061533
# 527    KEY       32853676032  Financial Services                     1.208707
# 210    MET       92796944384  Financial Services                     3.414055
# 235   PCAR       57322881024         Industrials                     2.108943
# 101    IBN     1787881062400  Financial Services                    65.777221
# 986   VOYA       11104132096  Financial Services                     0.408528
# 902   CELH        7302352384  Consumer Defensive                     0.268658
# 947   CWST        7868419584         Industrials                     0.289484

# %% [markdown]
# ## Grouping and Aggregation
#
# Sometimes we want to **summarize data by category**. For example: *"What is the total market cap for each sector?"*
#
# The idea is simple — split the data into groups (one per sector), then compute a summary for each group.
#
# We do this in three steps:
#
# 1. **Group** the rows by a column (e.g., `sector`) using `groupby()`
# 2. **Pick** the column we want to summarize (e.g., `market_cap`)
# 3. **Apply** one or more summary functions (`sum`, `mean`, `count`)

# %%
# Step 1: Group the rows by 'sector'
grouped = df_sample.groupby('sector')
print('Step 1 — type:', type(grouped).__name__)
print('Number of groups:', grouped.ngroups)
print('Group sizes:')
print(grouped.size())
print()

# Let's peek inside one group to see what it looks like
print('--- Example: the "Technology" group ---')
print(grouped.get_group('Technology'))
print()

# Step 2: Select the 'market_cap' column from each group
market_cap_by_sector = grouped['market_cap']
print('Step 2 — now we only keep the market_cap values per group:')
for name, values in market_cap_by_sector:
    print(f'  {name}: {values.tolist()}')
print()

# Step 3: Apply summary functions — sum, mean, and count
df_grouped = market_cap_by_sector.agg(['sum', 'mean', 'count'])
print('Step 3 — after agg():')
print(df_grouped)
print()
# Notice: 'sector' is now the index, not a regular column

# reset_index() turns 'sector' back into a regular column
df_grouped = df_grouped.reset_index()
print('After reset_index():')
print(df_grouped)

# NOTE: The 4 steps above can also be written in one line:
# df_grouped = df_sample.groupby('sector')['market_cap'].agg(['sum', 'mean', 'count']).reset_index()
# Out:
# Step 1 — type: DataFrameGroupBy
# Number of groups: 8
# Group sizes:
# sector
# Consumer Cyclical     3
# Consumer Defensive    2
# Financial Services    7
# Healthcare            3
# Industrials           8
# Real Estate           2
# Technology            3
# Utilities             2
# dtype: int64
#
# --- Example: the "Technology" group ---
#     symbol              company_name      sector  \
# 740   COHR            Coherent Corp.  Technology
# 859   CACI  CACI International, Inc.  Technology
# 280    GLW      Corning Incorporated  Technology
#
#                                industry   market_cap  enterprise_value  \
# 740  Scientific & Technical Instruments  10647828480       16518365184
# 859     Information Technology Services   8287675392       11469899776
# 280               Electronic Components  41688969216       48276049920
#
#      current_price  previous_close  fifty_two_week_high  fifty_two_week_low  \
# 740      68.239998       68.709999           113.599998           48.779999
# 859     366.119995      369.660004           588.260010          318.600006
# 280      48.529999       48.669998            55.330002           30.719999
#
#      ...  average_volume  short_ratio  exchange  exchange_short_name  \
# 740  ...         3784373         1.25       NYQ                  NYQ
# 859  ...          499506         2.23       NYQ                  NYQ
# 280  ...         5691203         2.03       NYQ                  NYQ
#
#            country  is_etf  is_fund  is_actively_trading            timestamp  \
# 740  United States       0        0                    1  2025-03-22 05:08:03
# 859  United States       0        0                    1  2025-03-22 05:08:21
# 280  United States       0        0                    1  2025-03-22 04:53:27
#
#      market_cap_%
# 740      1.228960
# 859      0.956554
# 280      4.811693
#
# [3 rows x 39 columns]
#
# Step 2 — now we only keep the market_cap values per group:
#   Consumer Cyclical: [12547034112, 25068689408, 7802572288]
#   Consumer Defensive: [34828255232, 7742831104]
#   Financial Services: [18602571776, 13326393344, 69434900480, 17847687168, 56351207424, 110510989312, 6531132928]
#   Healthcare: [6612871168, 7148292608, 29350852608]
#   Industrials: [18167234560, 13923810304, 141880508416, 7950121472, 10036755456, 16714461184, 51611635712, 7024250880]
#   Real Estate: [12082990080, 82899656704]
#   Technology: [10647828480, 8287675392, 41688969216]
#   Utilities: [10683482112, 9103995904]
#
# Step 3 — after agg():
#                              sum          mean  count
# sector
# Consumer Cyclical    45418295808  1.513943e+10      3
# Consumer Defensive   42571086336  2.128554e+10      2
# Financial Services  292604882432  4.180070e+10      7
# Healthcare           43112016384  1.437067e+10      3
# Industrials         267308777984  3.341360e+10      8
# Real Estate          94982646784  4.749132e+10      2
# Technology           60624473088  2.020816e+10      3
# Utilities            19787478016  9.893739e+09      2
#
# After reset_index():
#                sector           sum          mean  count
# 0   Consumer Cyclical   45418295808  1.513943e+10      3
# 1  Consumer Defensive   42571086336  2.128554e+10      2
# 2  Financial Services  292604882432  4.180070e+10      7
# 3          Healthcare   43112016384  1.437067e+10      3
# 4         Industrials  267308777984  3.341360e+10      8
# 5         Real Estate   94982646784  4.749132e+10      2
# 6          Technology   60624473088  2.020816e+10      3
# 7           Utilities   19787478016  9.893739e+09      2

# %% [markdown]
# ## Advanced Sorting and Indexing
#
# By default, a DataFrame uses row numbers (0, 1, 2, ...) as its index. But we can change the index to something more meaningful:
#
# - **`set_index('symbol')`** — use the stock symbol as the row label, so we can look up rows by name (e.g., `df.loc['PYPL']`)
# - **Multi-index** — use *two* columns as a combined index (e.g., `sector` + `symbol`), which organizes the data hierarchically
# - **Sorting by multiple columns** — for example, sort by `sector` alphabetically, and within each sector sort by `market_cap` from largest to smallest

# %%
# --- Using set_index() ---
# Replace the default numeric index with 'symbol', so each row is labeled by its stock ticker
df_indexed = df_sample.set_index('symbol')
print('--- DataFrame with symbol as index ---')
print(df_indexed)

# --- Multi-Index ---
# Use TWO columns as the index: first 'sector', then 'symbol'
# This creates a hierarchical structure: sector > symbol
df_multi_indexed = df_sample.set_index(['sector', 'symbol'])
print('\n--- DataFrame with Multi-Index (sector, symbol) ---')
print(df_multi_indexed)

# --- Sorting by multiple columns ---
# Sort by 'sector' A→Z (ascending=True), then within each sector
# sort by 'market_cap' from largest to smallest (ascending=False)
df_sorted_multi = df_sample.sort_values(
    by=['sector', 'market_cap'],
    ascending=[True, False]
)
print('\n--- DataFrame sorted by sector (A-Z) and market_cap (largest first) ---')
print(df_sorted_multi)
# Out:
# --- DataFrame with symbol as index ---
#                            company_name              sector  \
# symbol
# EME                   EMCOR Group, Inc.         Industrials
# WTRG          Essential Utilities, Inc.           Utilities
# COHR                     Coherent Corp.          Technology
# SN                     SharkNinja, Inc.   Consumer Cyclical
# ROL                       Rollins, Inc.   Consumer Cyclical
# BXP                           BXP, Inc.         Real Estate
# IEX                    IDEX Corporation         Industrials
# L                     Loews Corporation  Financial Services
# CACI           CACI International, Inc.          Technology
# EQIX                      Equinix, Inc.         Real Estate
# OGE                     OGE Energy Corp           Utilities
# UNP           Union Pacific Corporation         Industrials
# CNA           CNA Financial Corporation  Financial Services
# BBIO             BridgeBio Pharma, Inc.          Healthcare
# RVMD         Revolution Medicines, Inc.          Healthcare
# GPK     Graphic Packaging Holding Compa   Consumer Cyclical
# GLW                Corning Incorporated          Technology
# GNRC             Generac Holdlings Inc.         Industrials
# MTZ                        MasTec, Inc.         Industrials
# SYY                   Sysco Corporation  Consumer Defensive
# ZTO           ZTO Express (Cayman) Inc.         Industrials
# PYPL              PayPal Holdings, Inc.  Financial Services
# DXCM                       DexCom, Inc.          Healthcare
# KEY                             KeyCorp  Financial Services
# MET                       MetLife, Inc.  Financial Services
# PCAR                        PACCAR Inc.         Industrials
# IBN                  ICICI Bank Limited  Financial Services
# VOYA               Voya Financial, Inc.  Financial Services
# CELH             Celsius Holdings, Inc.  Consumer Defensive
# CWST        Casella Waste Systems, Inc.         Industrials
#
#                                    industry    market_cap  enterprise_value  \
# symbol
# EME              Engineering & Construction   18167234560       16978455552
# WTRG            Utilities - Regulated Water   10683482112       18454824960
# COHR     Scientific & Technical Instruments   10647828480       16518365184
# SN       Furnishings, Fixtures & Appliances   12547034112       12900748288
# OGE           0                    1  2025-03-22 05:08:02      1.050773
# UNP           0                    1  2025-03-22 04:50:56     16.375684
# CNA           0                    1  2025-03-22 05:30:13      1.538117
# BBIO          0                    1  2025-03-22 05:21:41      0.763250
# RVMD          0                    1  2025-03-22 05:16:14      0.825048
# GPK           0                    1  2025-03-22 05:11:48      0.900564
# GLW           0                    1  2025-03-22 04:53:27      4.811693
# GNRC          0                    1  2025-03-22 05:10:05      0.917594
# MTZ           0                    1  2025-03-22 05:11:44      1.158431
# SYY           0                    1  2025-03-22 04:53:32      4.019837
# ZTO           0                    1  2025-03-22 05:31:21      1.929164
# PYPL          0                    1  2025-03-22 04:52:04      8.014096
# DXCM          0                    1  2025-03-22 04:54:02      3.387641
# KEY           0                    1  2025-03-22 04:55:47      2.059959
# MET           0                    1  2025-03-22 04:53:06      6.503991
# PCAR          0                    1  2025-03-22 04:52:26      5.956955
# IBN           0                    1  2025-03-22 05:31:12     12.755051
# VOYA          0                    1  2025-03-22 05:12:07      0.753816
# CELH          0                    1  2025-03-22 05:10:41      0.893669
# CWST          0                    1  2025-03-22 05:10:34      0.810731
#
# [30 rows x 38 columns]
#
# --- DataFrame with Multi-Index (sector, symbol) ---
#                                               company_name  \
# sector             symbol
# Industrials        EME                   EMCOR Group, Inc.
# Utilities          WTRG          Essential Utilities, Inc.
# Technology         COHR                     Coherent Corp.
# Consumer Cyclical  SN                     SharkNinja, Inc.
#                    ROL                       Rollins, Inc.
# Real Estate        BXP                           BXP, Inc.
# Industrials        IEX                    IDEX Corporation
# Financial Services L                     Loews Corporation
# Technology         CACI           CACI International, Inc.
# Real Estate        EQIX                      Equinix, Inc.
# Utilities          OGE                     OGE Energy Corp
# Industrials        UNP           Union Pacific Corporation
# Financial Services CNA           CNA Financial Corporation
# Healthcare         BBIO             BridgeBio Pharma, Inc.
#                    RVMD         Revolution Medicines, Inc.
# Consumer Cyclical  GPK     Graphic Packaging Holding Compa
# Technology         GLW                Corning Incorporated
# Industrials        GNRC             Generac Holdlings Inc.
#                    MTZ                        MasTec, Inc.
# Consumer Defensive SYY                   Sysco Corporation
# Industrials        ZTO           ZTO Express (Cayman) Inc.
# Financial Services PYPL              PayPal Holdings, Inc.
# Healthcare         DXCM                       DexCom, Inc.
# Financial Services KEY                             KeyCorp
#                    MET                       MetLife, Inc.
# Industrials        PCAR                        PACCAR Inc.
# Financial Services IBN                  ICICI Bank Limited
#                    VOYA               Voya Financial, Inc.
# Consumer Defensive CELH             Celsius Holdings, Inc.
# Industrials        CWST        Casella Waste Systems, Inc.
#
#                                                       industry    market_cap  \
# sector             symbol
# Industrials        EME              Engineering & Construction   18167234560
# Utilities          WTRG            Utilities - Regulated Water   10683482112
# Technology         COHR     Scientific & Technical Instruments   10647828480
# Consumer Cyclical  SN       Furnishings, Fixtures & Appliances   12547034112
#                    ROL                       Personal Services   25068689408
# Real Estate        BXP                           REIT - Office   12082990080
# Industrials        IEX          Specialty Industrial Machinery   13923810304
# Financial Services L           Insurance - Property & Casualty   18602571776
# Technology         CACI        Information Technology Services    8287675392
# Real Estate        EQIX                       REIT - Specialty   82899656704
# Utilities          OGE          Utilities - Regulated Electric    9103995904
# Industrials        UNP                               Railroads  141880508416
# Financial Services CNA         Insurance - Property & Casualty   13326393344
# Healthcare         BBIO                          Biotechnology    6612871168
#                    RVMD                          Biotechnology    7148292608
# Consumer Cyclical  GPK                  Packaging & Containers    7802572288
# Technology         GLW                   Electronic Components   41688969216
# Industrials        GNRC         Specialty Industrial Machinery    7950121472
#                    MTZ              Engineering & Construction   10036755456
# Consumer Defensive SYY                       Food Distribution   34828255232
# Industrials        ZTO          Integrated Freight & Logistics   16714461184
# Financial Services PYPL                        Credit Services   69434900480
# Healthcare         DXCM                        Medical Devices   29350852608
# Financial Services KEY                        Banks - Regional   17847687168
#                    MET                        Insurance - Life   56351207424
# Industrials        PCAR    Farm & Heavy Construction Machinery   51611635712
# Financial Services IBN                        Banks - Regional  110510989312
#                    VOYA                Financial Conglomerates    6531132928
# Consumer Defensive CELH              Beverages - Non-Alcoholic    7742831104
# Industrials        CWST                       Waste Management    7024250880
#
#                            enterprise_value  current_price  previous_close  \
# sector             symbol
# Industrials        EME          16978455552     395.140015      399.519989
# Utilities          WTRG         18454824960      38.509998       38.860001
# Technology         COHR         16518365184      68.239998       68.709999
# Consumer Cyclical  SN           12900748288      87.949997       89.400002
#                    ROL          25722433536      51.630001       51.680000
# Real Estate        BXP          29060794368      68.339996       68.470001
# Industrials        IEX          15252375552     181.910004      183.729996
# Financial Services L            22880147456      87.250000       88.180000
# Technology         CACI         11469899776     366.119995      369.660004
# Real Estate        EQIX         97136320512     834.590027      851.719971
# Utilities          OGE          14598353920      44.959999       45.259998
# Industrials        UNP         172757499904     233.880005      234.789993
# Financial Services CNA          13978393600      48.740002       49.200001
# Healthcare         BBIO          7509071360      34.770000       33.910000
#                    RVMD          4931700736      38.110001       38.490002
# Consumer Cyclical  GPK          12892424192      25.290001       25.990000
# Technology         GLW          48276049920      48.529999       48.669998
# Industrials        GNRC          8955035648     131.520004      133.360001
#                    MTZ          12001590272     124.029999      126.580002
# Consumer Defensive SYY          47703121920      71.110001       71.190002
# Industrials        ZTO          11656066048      20.049999       20.139999
# Financial Services PYPL         70468927488      70.190002       69.669998
# Healthcare         DXCM         28853374976      73.800003       75.110001
# Financial Services KEY          32853676032      16.150000       16.090000
#                    MET          92796944384      82.360001       82.720001
# Industrials        PCAR         57322881024      97.110001       98.320000
# Financial Services IBN        1787881062400      31.280001       30.639999
#                    VOYA         11104132096      67.889999       68.370003
# Consumer Defensive CELH          7302352384      32.930000       31.250000
# Industrials        CWST          7868419584     110.459999      110.790001
#
#                            fifty_two_week_high  fifty_two_week_low  \
# sector             symbol
# Industrials        EME              545.289978          319.489990
# Utilities          WTRG              41.779999           33.180000
# Technology         COHR             113.599998           48.779999
# Consumer Cyclical  SN               123.000000           59.779999
#                    ROL               53.720001           41.720001
# Real Estate        BXP               90.110001           56.459999
# Industrials        IEX              245.699997          177.710007
# Financial Services L                 88.660004           72.910004
# Technology         CACI             588.260010          318.600006
# Real Estate        EQIX             994.030029          684.140015
# Utilities          OGE               46.540001           32.369999
# Industrials        UNP              258.070007          218.550003
# Financial Services CNA               52.360001           42.330002
# Healthcare         BBIO              39.470001           21.620001
#                    RVMD              62.400002           29.549999
# Consumer Cyclical  GPK               30.700001           25.129999
# Technology         GLW               55.330002           30.719999
# Industrials        GNRC             195.940002          115.760002
#                    MTZ              166.949997           82.290001
# Consumer Defensive SYY               82.330002           69.029999
# Industrials        ZTO               27.500000           17.889999
# Financial Services PYPL              93.660004           56.970001
# Healthcare         DXCM             142.000000           62.340000
# Financial Services KEY               20.040001           13.110000
#                    MET               89.050003           67.300003
# Industrials        PCAR             125.500000           90.040001
# Financial Services IBN               32.139999           25.129999
#                    VOYA              84.300003           64.099998
# Consumer Defensive CELH              98.849998           21.100000
# Industrials        CWST             116.309998           86.410004
#
#                            fifty_day_average  two_hundred_day_avg  ...  \
# sector             symbol                                          ...
# Industrials        EME            434.638000           424.240265  ...
# Utilities          WTRG            36.572800            38.209450  ...
# Technology         COHR            82.873398            84.968903  ...
# Consumer Cyclical  SN             103.621399            95.359848  ...
#                    ROL             50.211201            49.305851  ...
# Real Estate        BXP             70.132401            73.328247  ...
# Industrials        IEX            200.276398           206.974304  ...
# Financial Services L               85.139603            81.205254  ...
# Technology         CACI           381.334595           446.273651  ...
# Real Estate        EQIX           903.611389           869.697876  ...
# Utilities          OGE             43.533401            40.636051  ...
# Industrials        UNP            242.170593           238.786652  ...
# Financial Services CNA             48.665600            48.412701  ...
# Healthcare         BBIO            33.871399            28.105150  ...
#                    RVMD            40.657398            44.638100  ...
# Consumer Cyclical  GPK             26.888000            28.069851  ...
# Technology         GLW             49.761799            45.467449  ...
# Industrials        GNRC           143.572006           154.222397  ...
#                    MTZ            135.604202           124.442848  ...
# Consumer Defensive SYY             73.197800            74.874153  ...
# Industrials        ZTO             19.503799            20.915751  ...
# Financial Services PYPL            78.224899            75.179474  ...
# Healthcare         DXCM            83.018600            82.690399  ...
# Financial Services KEY             17.028601            16.653950  ...
#                    MET             83.348000            79.326851  ...
# Industrials        PCAR           106.267799           104.600548  ...
# Financial Services IBN             28.675600            29.186550  ...
#                    VOYA            70.240196            73.341301  ...
# Consumer Defensive CELH            26.232201            35.766251  ...
# Industrials        CWST           109.541603           105.204300  ...
#
#                            average_volume  short_ratio  exchange  \
# sector             symbol
# Industrials        EME             498055         1.66       NYQ
# Utilities          WTRG           1531478         3.20       NYQ
# Technology         COHR           3784373         1.25       NYQ
# Consumer Cyclical  SN             1204118         2.26       NYQ
#                    ROL            1743935         3.01       NYQ
# Real Estate        BXP            1307363         8.04       NYQ
# Industrials        IEX             542796         1.84       NYQ
# Financial Services L               752170         3.16       NYQ
# Technology         CACI            499506         2.23       NYQ
# Real Estate        EQIX            592406         3.57       NMS
# Utilities          OGE            1132858         4.80       NYQ
# Industrials        UNP            2611048         2.82       NYQ
# Financial Services CNA             341765         2.48       NYQ
# Technology         GLW           0                    1  2025-03-22 04:53:27
# Industrials        GNRC          0                    1  2025-03-22 05:10:05
#                    MTZ           0                    1  2025-03-22 05:11:44
# Consumer Defensive SYY           0                    1  2025-03-22 04:53:32
# Industrials        ZTO           0                    1  2025-03-22 05:31:21
# Financial Services PYPL          0                    1  2025-03-22 04:52:04
# Healthcare         DXCM          0                    1  2025-03-22 04:54:02
# Financial Services KEY           0                    1  2025-03-22 04:55:47
#                    MET           0                    1  2025-03-22 04:53:06
# Industrials        PCAR          0                    1  2025-03-22 04:52:26
# Financial Services IBN           0                    1  2025-03-22 05:31:12
#                    VOYA          0                    1  2025-03-22 05:12:07
# Consumer Defensive CELH          0                    1  2025-03-22 05:10:41
# Industrials        CWST          0                    1  2025-03-22 05:10:34
#
#                            market_cap_%
# sector             symbol
# Industrials        EME         2.096841
# Utilities          WTRG        1.233075
# Technology         COHR        1.228960
# Consumer Cyclical  SN          1.448164
#                    ROL         2.893399
# Real Estate        BXP         1.394605
# Industrials        IEX         1.607070
# Financial Services L           2.147087
# Technology         CACI        0.956554
# Real Estate        EQIX        9.568182
# Utilities          OGE         1.050773
# Industrials        UNP        16.375684
# Financial Services CNA         1.538117
# Healthcare         BBIO        0.763250
#                    RVMD        0.825048
# Consumer Cyclical  GPK         0.900564
# Technology         GLW         4.811693
# Industrials        GNRC        0.917594
#                    MTZ         1.158431
# Consumer Defensive SYY         4.019837
# Industrials        ZTO         1.929164
# Financial Services PYPL        8.014096
# Healthcare         DXCM        3.387641
# Financial Services KEY         2.059959
#                    MET         6.503991
# Industrials        PCAR        5.956955
# Financial Services IBN        12.755051
#                    VOYA        0.753816
# Consumer Defensive CELH        0.893669
# Industrials        CWST        0.810731
#
# [30 rows x 37 columns]
#
# --- DataFrame sorted by sector (A-Z) and market_cap (largest first) ---
#     symbol                     company_name              sector  \
# 411    ROL                    Rollins, Inc.   Consumer Cyclical
# 660     SN                 SharkNinja, Inc.   Consumer Cyclical
# 899    GPK  Graphic Packaging Holding Compa   Consumer Cyclical
# 319    SYY                Sysco Corporation  Consumer Defensive
# 902   CELH           Celsius Holdings, Inc.  Consumer Defensive
# 101    IBN               ICICI Bank Limited  Financial Services
# 174   PYPL            PayPal Holdings, Inc.  Financial Services
# 210    MET                    MetLife, Inc.  Financial Services
# 513      L                Loews Corporation  Financial Services
# 527    KEY                          KeyCorp  Financial Services
# 636    CNA        CNA Financial Corporation  Financial Services
# 986   VOYA             Voya Financial, Inc.  Financial Services
# 371   DXCM                     DexCom, Inc.          Healthcare
# 938   RVMD       Revolution Medicines, Inc.          Healthcare
# 973   BBIO           BridgeBio Pharma, Inc.          Healthcare
# 76     UNP        Union Pacific Corporation         Industrials
# 235   PCAR                      PACCAR Inc.         Industrials
# 521    EME                EMCOR Group, Inc.         Industrials
# 549    ZTO        ZTO Express (Cayman) Inc.         Industrials
# 626    IEX                 IDEX Corporation         Industrials
# 761    MTZ                     MasTec, Inc.         Industrials
# 883   GNRC           Generac Holdlings Inc.         Industrials
# 761  United States       0        0                    1  2025-03-22 05:11:44
# 883  United States       0        0                    1  2025-03-22 05:10:05
# 947  United States       0        0                    1  2025-03-22 05:10:34
# 136  United States       0        0                    1  2025-03-22 04:51:32
# 678  United States       0        0                    1  2025-03-22 05:17:24
# 280  United States       0        0                    1  2025-03-22 04:53:27
# 740  United States       0        0                    1  2025-03-22 05:08:03
# 859  United States       0        0                    1  2025-03-22 05:08:21
# 737  United States       0        0                    1  2025-03-22 04:57:46
# 811  United States       0        0                    1  2025-03-22 05:08:02
#
#      market_cap_%
# 411      2.893399
# 660      1.448164
# 899      0.900564
# 319      4.019837
# 902      0.893669
# 101     12.755051
# 174      8.014096
# 210      6.503991
# 513      2.147087
# 527      2.059959
# 636      1.538117
# 986      0.753816
# 371      3.387641
# 938      0.825048
# 973      0.763250
# 76      16.375684
# 235      5.956955
# 521      2.096841
# 549      1.929164
# 626      1.607070
# 761      1.158431
# 883      0.917594
# 947      0.810731
# 136      9.568182
# 678      1.394605
# 280      4.811693
# 740      1.228960
# 859      0.956554
# 737      1.233075
# 811      1.050773
#
# [30 rows x 39 columns]

# %% [markdown]
# ## Filtering Rows with Conditions
#
# We often need to **select only the rows that meet certain criteria**. For example:
# *"Show me only Technology and Financial Services companies with a market cap above average."*
#
# How it works:
# 1. A **condition** like `df['market_cap'] > 100` produces a column of `True`/`False` values (called a **boolean mask**)
# 2. We can combine multiple conditions with `&` (AND) or `|` (OR)
# 3. Passing the mask inside `df[...]` keeps only the rows where the result is `True`

# %%
# First, compute the average market_cap (we need this as our threshold)
average_market_cap = df_sample['market_cap'].mean()
print(f'Average market cap: {average_market_cap:,.0f}')

# Condition 1: market_cap is above average
above_average = df_sample['market_cap'] > average_market_cap

# Condition 2: sector is either "Technology" or "Financial Services"
# isin() checks if each value is in the given list
selected_sectors = df_sample['sector'].isin(['Technology', 'Financial Services'])

# Combine both conditions with & (AND) — both must be True
condition = above_average & selected_sectors

# Apply the filter: keep only rows where condition is True
df_filtered = df_sample[condition]

print('\n--- Filtered: market_cap > average AND sector is Technology or Financial Services ---')
print(df_filtered)
# Out:
# Average market cap: 28,880,321,894
#
# --- Filtered: market_cap > average AND sector is Technology or Financial Services ---
#     symbol           company_name              sector               industry  \
# 280    GLW   Corning Incorporated          Technology  Electronic Components
# 174   PYPL  PayPal Holdings, Inc.  Financial Services        Credit Services
# 210    MET          MetLife, Inc.  Financial Services       Insurance - Life
# 101    IBN     ICICI Bank Limited  Financial Services       Banks - Regional
#
#        market_cap  enterprise_value  current_price  previous_close  \
# 280   41688969216       48276049920      48.529999       48.669998
# 174   69434900480       70468927488      70.190002       69.669998
# 210   56351207424       92796944384      82.360001       82.720001
# 101  110510989312     1787881062400      31.280001       30.639999
#
#      fifty_two_week_high  fifty_two_week_low  ...  average_volume  \
# 280            55.330002           30.719999  ...         5691203
# 174            93.660004           56.970001  ...        11242598
# 210            89.050003           67.300003  ...         3356425
# 101            32.139999           25.129999  ...         4283705
#
#      short_ratio  exchange  exchange_short_name        country  is_etf  \
# 280         2.03       NYQ                  NYQ  United States       0
# 174         2.51       NMS                  NMS  United States       0
# 210         2.06       NYQ                  NYQ  United States       0
# 101         6.12       NYQ                  NYQ          India       0
#
#      is_fund  is_actively_trading            timestamp  market_cap_%
# 280        0                    1  2025-03-22 04:53:27      4.811693
# 174        0                    1  2025-03-22 04:52:04      8.014096
# 210        0                    1  2025-03-22 04:53:06      6.503991
# 101        0                    1  2025-03-22 05:31:12     12.755051
#
# [4 rows x 39 columns]

# %% [markdown]
# ## Operations on Text (String) Columns
#
# Pandas provides string methods via `.str` to work with text data. In this section we will:
#
# - Get the **unique values** in a column and count how often each appears
# - **Convert** text to uppercase
# - **Search** for rows containing a specific word
# - **Replace** specific values with new ones
# - **Map** values to a simplified version using a dictionary

# %%
# --- Getting unique values ---
unique_sectors = df_sample['sector'].unique()
print('--- Unique Sectors ---')
print(unique_sectors)

# --- Counting occurrences ---
# How many companies are in each sector?
sector_counts = df_sample['sector'].value_counts()
print('\n--- Count of Each Sector ---')
print(sector_counts)

# --- Converting text to uppercase ---
# .str gives access to string methods on a whole column
df_sample['sector_upper'] = df_sample['sector'].str.upper()
print('\n--- DataFrame with uppercase sector column added ---')
print(df_sample)

# --- Searching for text inside a column ---
# Find all rows where 'sector' contains the word "tech" (case-insensitive)
df_tech = df_sample[df_sample['sector'].str.contains('tech', case=False, na=False)]
print('\n--- Rows where sector contains "tech" ---')
print(df_tech)

# --- Replacing specific values ---
# Change "Financial Services" to "Finance" everywhere in the column
df_sample['sector_replaced'] = df_sample['sector'].replace({'Financial Services': 'Finance'})
print('\n--- DataFrame with "Financial Services" replaced by "Finance" ---')
print(df_sample)

# --- Mapping values using a dictionary ---
# map() replaces values that match a key; non-matching values become NaN
sector_mapping = {
    'Technology': 'Tech',
    'Financial Services': 'Finance',
    'Industrials': 'Industrial'
}
df_sample['sector_mapped'] = df_sample['sector'].map(sector_mapping)
print('\n--- DataFrame with mapped sector names (unmatched sectors become NaN) ---')
print(df_sample)
# Out:
# --- Unique Sectors ---
# ['Industrials' 'Utilities' 'Technology' 'Consumer Cyclical' 'Real Estate'
#  'Financial Services' 'Healthcare' 'Consumer Defensive']
#
# --- Count of Each Sector ---
# sector
# Industrials           8
# Financial Services    7
# Technology            3
# Consumer Cyclical     3
# Healthcare            3
# Utilities             2
# Real Estate           2
# Consumer Defensive    2
# Name: count, dtype: int64
#
# --- DataFrame with uppercase sector column added ---
#     symbol                     company_name              sector  \
# 521    EME                EMCOR Group, Inc.         Industrials
# 737   WTRG        Essential Utilities, Inc.           Utilities
# 740   COHR                   Coherent Corp.          Technology
# 660     SN                 SharkNinja, Inc.   Consumer Cyclical
# 411    ROL                    Rollins, Inc.   Consumer Cyclical
# 678    BXP                        BXP, Inc.         Real Estate
# 626    IEX                 IDEX Corporation         Industrials
# 513      L                Loews Corporation  Financial Services
# 859   CACI         CACI International, Inc.          Technology
# 136   EQIX                    Equinix, Inc.         Real Estate
# 811    OGE                  OGE Energy Corp           Utilities
# 76     UNP        Union Pacific Corporation         Industrials
# 859        0                    1  2025-03-22 05:08:21      0.956554
# 136        0                    1  2025-03-22 04:51:32      9.568182
# 811        0                    1  2025-03-22 05:08:02      1.050773
# 76         0                    1  2025-03-22 04:50:56     16.375684
# 636        0                    1  2025-03-22 05:30:13      1.538117
# 973        0                    1  2025-03-22 05:21:41      0.763250
# 938        0                    1  2025-03-22 05:16:14      0.825048
# 899        0                    1  2025-03-22 05:11:48      0.900564
# 280        0                    1  2025-03-22 04:53:27      4.811693
# 883        0                    1  2025-03-22 05:10:05      0.917594
# 761        0                    1  2025-03-22 05:11:44      1.158431
# 319        0                    1  2025-03-22 04:53:32      4.019837
# 549        0                    1  2025-03-22 05:31:21      1.929164
# 174        0                    1  2025-03-22 04:52:04      8.014096
# 371        0                    1  2025-03-22 04:54:02      3.387641
# 527        0                    1  2025-03-22 04:55:47      2.059959
# 210        0                    1  2025-03-22 04:53:06      6.503991
# 235        0                    1  2025-03-22 04:52:26      5.956955
# 101        0                    1  2025-03-22 05:31:12     12.755051
# 986        0                    1  2025-03-22 05:12:07      0.753816
# 902        0                    1  2025-03-22 05:10:41      0.893669
# 947        0                    1  2025-03-22 05:10:34      0.810731
#
#            sector_upper
# 521         INDUSTRIALS
# 737           UTILITIES
# 740          TECHNOLOGY
# 660   CONSUMER CYCLICAL
# 411   CONSUMER CYCLICAL
# 678         REAL ESTATE
# 626         INDUSTRIALS
# 513  FINANCIAL SERVICES
# 859          TECHNOLOGY
# 136         REAL ESTATE
# 811           UTILITIES
# 76          INDUSTRIALS
# 636  FINANCIAL SERVICES
# 973          HEALTHCARE
# 938          HEALTHCARE
# 899   CONSUMER CYCLICAL
# 280          TECHNOLOGY
# 883         INDUSTRIALS
# 761         INDUSTRIALS
# 319  CONSUMER DEFENSIVE
# 549         INDUSTRIALS
# 174  FINANCIAL SERVICES
# 371          HEALTHCARE
# 527  FINANCIAL SERVICES
# 210  FINANCIAL SERVICES
# 235         INDUSTRIALS
# 101  FINANCIAL SERVICES
# 986  FINANCIAL SERVICES
# 902  CONSUMER DEFENSIVE
# 947         INDUSTRIALS
#
# [30 rows x 40 columns]
#
# --- Rows where sector contains "tech" ---
#     symbol              company_name      sector  \
# 740   COHR            Coherent Corp.  Technology
# 859   CACI  CACI International, Inc.  Technology
# 280    GLW      Corning Incorporated  Technology
#
#                                industry   market_cap  enterprise_value  \
# 740  Scientific & Technical Instruments  10647828480       16518365184
# 859     Information Technology Services   8287675392       11469899776
# 280               Electronic Components  41688969216       48276049920
#
#      current_price  previous_close  fifty_two_week_high  fifty_two_week_low  \
# 740      68.239998       68.709999           113.599998           48.779999
# 859     366.119995      369.660004           588.260010          318.600006
# 280      48.529999       48.669998            55.330002           30.719999
#
#      ...  short_ratio  exchange  exchange_short_name        country  is_etf  \
# 740  ...         1.25       NYQ                  NYQ  United States       0
# 859  ...         2.23       NYQ                  NYQ  United States       0
# 280  ...         2.03       NYQ                  NYQ  United States       0
#
#      is_fund  is_actively_trading            timestamp  market_cap_%  \
# 740        0                    1  2025-03-22 05:08:03      1.228960
# 859        0                    1  2025-03-22 05:08:21      0.956554
# 280        0                    1  2025-03-22 04:53:27      4.811693
#
#      sector_upper
# 740    TECHNOLOGY
# 859    TECHNOLOGY
# 280    TECHNOLOGY
#
# [3 rows x 40 columns]
#
# --- DataFrame with "Financial Services" replaced by "Finance" ---
#     symbol                     company_name              sector  \
# 521    EME                EMCOR Group, Inc.         Industrials
# 737   WTRG        Essential Utilities, Inc.           Utilities
# 740   COHR                   Coherent Corp.          Technology
# 660     SN                 SharkNinja, Inc.   Consumer Cyclical
# 411    ROL                    Rollins, Inc.   Consumer Cyclical
# 678    BXP                        BXP, Inc.         Real Estate
# 626    IEX                 IDEX Corporation         Industrials
# 513      L                Loews Corporation  Financial Services
# 859   CACI         CACI International, Inc.          Technology
# 136   EQIX                    Equinix, Inc.         Real Estate
# 811    OGE                  OGE Energy Corp           Utilities
# 76     UNP        Union Pacific Corporation         Industrials
# 636    CNA        CNA Financial Corporation  Financial Services
# 973   BBIO           BridgeBio Pharma, Inc.          Healthcare
# 938   RVMD       Revolution Medicines, Inc.          Healthcare
# 899    GPK  Graphic Packaging Holding Compa   Consumer Cyclical
# 280    GLW             Corning Incorporated          Technology
# 883   GNRC           Generac Holdlings Inc.         Industrials
# 761    MTZ                     MasTec, Inc.         Industrials
# 319    SYY                Sysco Corporation  Consumer Defensive
# 549    ZTO        ZTO Express (Cayman) Inc.         Industrials
# 174   PYPL            PayPal Holdings, Inc.  Financial Services
# 371   DXCM                     DexCom, Inc.          Healthcare
# 527    KEY                          KeyCorp  Financial Services
# 210    MET                    MetLife, Inc.  Financial Services
# 235   PCAR                      PACCAR Inc.         Industrials
# 101    IBN               ICICI Bank Limited  Financial Services
# 986   VOYA             Voya Financial, Inc.  Financial Services
# 902   CELH           Celsius Holdings, Inc.  Consumer Defensive
# 947   CWST      Casella Waste Systems, Inc.         Industrials
#
#                                 industry    market_cap  enterprise_value  \
# 521           Engineering & Construction   18167234560       16978455552
# 737          Utilities - Regulated Water   10683482112       18454824960
# 740   Scientific & Technical Instruments   10647828480       16518365184
# 660   Furnishings, Fixtures & Appliances   12547034112       12900748288
# 411                    Personal Services   25068689408       25722433536
# 678                        REIT - Office   12082990080       29060794368
# 626       Specialty Industrial Machinery   13923810304       15252375552
# 513      Insurance - Property & Casualty   18602571776       22880147456
# 859      Information Technology Services    8287675392       11469899776
# 136                     REIT - Specialty   82899656704       97136320512
# 811       Utilities - Regulated Electric    9103995904       14598353920
# 76                             Railroads  141880508416      172757499904
# 636      Insurance - Property & Casualty   13326393344       13978393600
# 973                        Biotechnology    6612871168        7509071360
# 938                        Biotechnology    7148292608        4931700736
# 899               Packaging & Containers    7802572288       12892424192
# 280                Electronic Components   41688969216       48276049920
# 883       Specialty Industrial Machinery    7950121472        8955035648
# 761           Engineering & Construction   10036755456       12001590272
# 319                    Food Distribution   34828255232       47703121920
# 549       Integrated Freight & Logistics   16714461184       11656066048
# 174                      Credit Services   69434900480       70468927488
# 986  FINANCIAL SERVICES             Finance
# 902  CONSUMER DEFENSIVE  Consumer Defensive
# 947         INDUSTRIALS         Industrials
#
# [30 rows x 41 columns]
#
# --- DataFrame with mapped sector names (unmatched sectors become NaN) ---
#     symbol                     company_name              sector  \
# 521    EME                EMCOR Group, Inc.         Industrials
# 737   WTRG        Essential Utilities, Inc.           Utilities
# 740   COHR                   Coherent Corp.          Technology
# 660     SN                 SharkNinja, Inc.   Consumer Cyclical
# 411    ROL                    Rollins, Inc.   Consumer Cyclical
# 678    BXP                        BXP, Inc.         Real Estate
# 626    IEX                 IDEX Corporation         Industrials
# 513      L                Loews Corporation  Financial Services
# 859   CACI         CACI International, Inc.          Technology
# 136   EQIX                    Equinix, Inc.         Real Estate
# 811    OGE                  OGE Energy Corp           Utilities
# 76     UNP        Union Pacific Corporation         Industrials
# 636    CNA        CNA Financial Corporation  Financial Services
# 973   BBIO           BridgeBio Pharma, Inc.          Healthcare
# 938   RVMD       Revolution Medicines, Inc.          Healthcare
# 899    GPK  Graphic Packaging Holding Compa   Consumer Cyclical
# 280    GLW             Corning Incorporated          Technology
# 883   GNRC           Generac Holdlings Inc.         Industrials
# 761    MTZ                     MasTec, Inc.         Industrials
# 319    SYY                Sysco Corporation  Consumer Defensive
# 549    ZTO        ZTO Express (Cayman) Inc.         Industrials
# 174   PYPL            PayPal Holdings, Inc.  Financial Services
# 371   DXCM                     DexCom, Inc.          Healthcare
# 527    KEY                          KeyCorp  Financial Services
# 210    MET                    MetLife, Inc.  Financial Services
# 235   PCAR                      PACCAR Inc.         Industrials
# 101    IBN               ICICI Bank Limited  Financial Services
# 986   VOYA             Voya Financial, Inc.  Financial Services
# 902   CELH           Celsius Holdings, Inc.  Consumer Defensive
# 947   CWST      Casella Waste Systems, Inc.         Industrials
#
#                                 industry    market_cap  enterprise_value  \
# 521           Engineering & Construction   18167234560       16978455552
# 737          Utilities - Regulated Water   10683482112       18454824960
# 740   Scientific & Technical Instruments   10647828480       16518365184
# 660   Furnishings, Fixtures & Appliances   12547034112       12900748288
# 411                    Personal Services   25068689408       25722433536
# 678                        REIT - Office   12082990080       29060794368
# 626       Specialty Industrial Machinery   13923810304       15252375552
# 513      Insurance - Property & Casualty   18602571776       22880147456
# 859      Information Technology Services    8287675392       11469899776
# 136                     REIT - Specialty   82899656704       97136320512
# 811       Utilities - Regulated Electric    9103995904       14598353920
# 76                             Railroads  141880508416      172757499904
# 636      Insurance - Property & Casualty   13326393344       13978393600
# 973                        Biotechnology    6612871168        7509071360
# 938                        Biotechnology    7148292608        4931700736
# 899               Packaging & Containers    7802572288       12892424192
# 280                Electronic Components   41688969216       48276049920
# 883       Specialty Industrial Machinery    7950121472        8955035648
# 761           Engineering & Construction   10036755456       12001590272
# 319                    Food Distribution   34828255232       47703121920
# 549       Integrated Freight & Logistics   16714461184       11656066048
# 174                      Credit Services   69434900480       70468927488
# 371                      Medical Devices   29350852608       28853374976
# 527                     Banks - Regional   17847687168       32853676032
# 210                     Insurance - Life   56351207424       92796944384
